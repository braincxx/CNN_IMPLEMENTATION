# %% [markdown]
# <a href="https://colab.research.google.com/github/braincxx/CNN_IMPLEMENTATION/blob/master/CNN_ALEXNET_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from timeit import default_timer as timer
from numba import vectorize

#@vectorize(['float32(float32, float32)'], target='cuda')
def pow(a, b):
    return a ** b

def main():
    vec_size = 30000000

    a = b = np.array(np.random.sample(vec_size), dtype=np.float32)
    c = np.zeros(vec_size, dtype=np.float32)

    start = timer()
    c = pow(a, b)
    duration = timer() - start

    print(duration)

if __name__ == '__main__':
    main()
# Out:
# 0.46024052600000687

# %%
import numpy as np 
import matplotlib.pyplot as plt 

number_of_points = 5000 
x_point = [] 
y_point = [] 
a = 1.5
b = 10 

for i in range(number_of_points): 
   x = np.random.normal()
   y = a*x + b + np.random.normal(0.0, 1) 
   x_point.append([x]) 
   y_point.append([y]) 
   
plt.plot(x_point,y_point, 'o', label = 'Input Data') 
plt.legend() 



plt.show()

# %%
 import numpy as np
from timeit import default_timer as timer
from numba import vectorize

@vectorize(['float32(float32, float32)'], target='cuda')
def pow(a, b):
    return a ** b

def main():
    vec_size = 30000000

    a = b = np.array(np.random.sample(vec_size), dtype=np.float32)
    c = np.zeros(vec_size, dtype=np.float32)

    start = timer()
    c = pow(a, b)
    duration = timer() - start

    print(duration)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# <ipython-input-20-c1ce5bae8ef3> in <module>()
#      20
#      21 if __name__ == '__main__':
# ---> 22    main()
#
# <ipython-input-20-c1ce5bae8ef3> in main()
#      14
#      15    start = timer()
# ---> 16    c = pow(a, b)
#      17    duration = timer() - start
#      18
#
# /usr/local/lib/python3.6/dist-packages/numba/cuda/dispatcher.py in __call__(self, *args, **kws)
#      86                       the input arguments.
#      87         """
# ---> 88         return CUDAUFuncMechanism.call(self.functions, args, kws)
#      89
#      90     def reduce(self, arg, stream=0):
#
# /usr/local/lib/python3.6/dist-packages/numba/npyufunc/deviceufunc.py in call(cls, typemap, args, kws)
#     292                 any_device = True
#     293             else:
# --> 294                 dev_a = cr.to_device(a, stream=stream)
# ...

# %% [markdown]
# # New Section

# %%
12.144336877 / 0.2513152320000245
# Out:
# 48.32312303696267

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
alexnet = tf.keras.models.Sequential()
# Out:
# Using TensorFlow backend.

# %%
import cv2
import numpy as np
from PIL import Image
img_shape = Image.open('g.jpg').resize((400, 300))

# Layer 1
alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape,
  padding='same') )
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 2
alexnet.add(Conv2D(256, (5, 5), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 3
alexnet.add(ZeroPadding2D((1, 1)))
alexnet.add(Conv2D(512, (3, 3), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 4
alexnet.add(ZeroPadding2D((1, 1)))
alexnet.add(Conv2D(1024, (3, 3), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))

# Layer 5
alexnet.add(ZeroPadding2D((1, 1)))
alexnet.add(Conv2D(1024, (3, 3), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 6
alexnet.add(Flatten())
alexnet.add(Dense(3072))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(Dropout(0.5))

# Layer 7
alexnet.add(Dense(4096))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(Dropout(0.5))

# Layer 8
alexnet.add(Dense(n_classes))
alexnet.add(BatchNormalization())
alexnet.add(Activation('softmax'))


'''
def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = np.random.random(100)
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
gpu()'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_default_graph()
#      65     try:
# ---> 66         return tf.get_default_graph()
#      67     except AttributeError:
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_graph'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-ec6d70d46b1f> in <module>()
#       6 # Layer 1
#       7 alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape,
# ----> 8   padding='same') )
#       9 alexnet.add(BatchNormalization())
#      10 alexnet.add(Activation('relu'))
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
# ...

# %%
import cv2
import numpy as np
from PIL import Image
img = Image.open('g.jpg').resize((400, 300))

data_image = np.asarray(img)
Image.fromarray(data_image).save('g_200.jpeg')
print(data_image.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8f368dbf90cf> in <module>()
#       2 import numpy as np
#       3 from PIL import Image
# ----> 4 img = Image.open('g.jpg').resize((400, 300))
#       5
#       6 data_image = np.asarray(img)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'g.jpg'

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

#Image.fromarray(train_images[1]).resize((320, 320)).save('123.jpeg')
#print(train_labels[1])
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# ...
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                65600
# ...

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=30, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.1305 - accuracy: 0.3162 - val_loss: 2.0597 - val_accuracy: 0.3898
# Epoch 2/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0116 - accuracy: 0.4430 - val_loss: 1.9650 - val_accuracy: 0.4930
# Epoch 3/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.9590 - accuracy: 0.4972 - val_loss: 1.9398 - val_accuracy: 0.5179
# Epoch 4/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.9272 - accuracy: 0.5305 - val_loss: 1.9266 - val_accuracy: 0.5293
# Epoch 5/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.8990 - accuracy: 0.5594 - val_loss: 1.9050 - val_accuracy: 0.5516
# Epoch 6/30
#   71/1563 [>.............................] - ETA: 5s - loss: 1.8861 - accuracy: 0.5704
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 1.5494 - accuracy: 0.6908

# %%
plt.figure(figsize=(10, 10))
test_x = test_images[25:51]
test_y = test_labels[25:51]
print(test_x.shape)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_x[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[test_y[i][0]])
plt.show()
# Out:
# (26, 32, 32, 3)

# %%
plt.figure(figsize = (10, 10))

for i in range(25):
    mas = model.predict(test_x[i:i + 1])
    result = np.where(mas == np.amax(mas))

    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_x[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[result[1][0]])
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 1.5494 - accuracy: 0.6908

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, ZeroPadding2D, BatchNormalization
from tensorflow.keras.regularizers import l2

alexnet = Sequential()

# %%
# Layer 1
alexnet.add(Conv2D(96, (11, 11), input_shape=(32, 32, 3),
  padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 2
alexnet.add(Conv2D(256, (5, 5), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 3
alexnet.add(ZeroPadding2D((1, 1)))
alexnet.add(Conv2D(512, (3, 3), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 4
alexnet.add(ZeroPadding2D((1, 1)))
alexnet.add(Conv2D(1024, (3, 3), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))

# Layer 5
alexnet.add(ZeroPadding2D((1, 1)))
alexnet.add(Conv2D(1024, (3, 3), padding='same'))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(MaxPooling2D(pool_size=(2, 2)))

# Layer 6
alexnet.add(Flatten())
alexnet.add(Dense(3072))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(Dropout(0.5))

# Layer 7
alexnet.add(Dense(4096))
alexnet.add(BatchNormalization())
alexnet.add(Activation('relu'))
alexnet.add(Dropout(0.5))

# Layer 8
alexnet.add(Dense(10))
alexnet.add(BatchNormalization())
alexnet.add(Activation('softmax'))

# %%
alexnet.compile(optimizer='Adam',
                loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

# %%
history = alexnet.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 150s 96ms/step - loss: 2.0831 - accuracy: 0.4068 - val_loss: 2.0476 - val_accuracy: 0.4179
# Epoch 2/10
# 1563/1563 [==============================] - 149s 95ms/step - loss: 1.9520 - accuracy: 0.5273 - val_loss: 1.9634 - val_accuracy: 0.5034
# Epoch 3/10
# 1563/1563 [==============================] - 149s 95ms/step - loss: 1.8863 - accuracy: 0.5860 - val_loss: 1.9503 - val_accuracy: 0.5129
# Epoch 4/10
# 1563/1563 [==============================] - 149s 95ms/step - loss: 1.8426 - accuracy: 0.6257 - val_loss: 1.8841 - val_accuracy: 0.5808
# Epoch 5/10
# 1563/1563 [==============================] - 148s 95ms/step - loss: 1.8045 - accuracy: 0.6637 - val_loss: 1.8398 - val_accuracy: 0.6267
# Epoch 6/10
# 1563/1563 [==============================] - 148s 95ms/step - loss: 1.7738 - accuracy: 0.6933 - val_loss: 1.9180 - val_accuracy: 0.5393
# Epoch 7/10
# ...

# %%
alexnet.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_27 (Conv2D)           (None, 32, 32, 96)        34944
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 32, 32, 96)        384
# _________________________________________________________________
# activation_23 (Activation)   (None, 32, 32, 96)        0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 16, 16, 256)       614656
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_24 (Activation)   (None, 16, 16, 256)       0
# ...

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = alexnet.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 7s - loss: 1.8011 - accuracy: 0.6587

# %%
alexnet.save('alexnet.h5')

# %%
alexnet.save_weights('al')

# %%
plt.figure(figsize = (10, 10))

for i in range(25):
    mas = alexnet.predict(test_x[i:i + 1])
    result = np.where(mas == np.amax(mas))

    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_x[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[result[1][0]])
plt.show()
print(alexnet.predict(test_x[i:i + 1]))
# Out:
# [[0.00378277 0.00111845 0.00400148 0.0015869  0.5693979  0.00163674
#   0.40538976 0.00783446 0.00355235 0.00169922]]
